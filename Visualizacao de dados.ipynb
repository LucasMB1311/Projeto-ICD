# %%
diet_df
# Out:
#              name emoji  Calories (kcal)  Carbohydrates (g)  Total Sugar (g)  \
# 0          grapes     🍇             0.69             0.1810           0.1548
# 1           melon     🍈             0.28             0.0658           0.0569
# 2      watermelon     🍉             0.30             0.0755           0.0620
# 3       tangerine     🍊             0.53             0.1334           0.1058
# 4           lemon     🍋             0.29             0.0932           0.0250
# 5          banana     🍌             0.89             0.2284           0.1223
# 6       pineapple     🍍             0.50             0.1312           0.0985
# 7       red apple     🍎             0.63             0.1522           0.1168
# 8     green apple     🍏             0.58             0.1361           0.0959
# 9            pear     🍐             0.57             0.1523           0.0975
# 10          peach     🍑             0.39             0.0954           0.0839
# ...

# %% [markdown]
# # Alimentos mais proteicos para a dieta

# %%
protein = diet_df[diet_df["Protein (g)"] >= 0.110]

# %%
sns.barplot(data = protein, x = "name",  y = "Protein (g)")
# Out:
# <AxesSubplot:xlabel='name', ylabel='Protein (g)'>

# %% [markdown]
# # Correlação entre carboidratos e proteinas de todos os alimentos para a dieta

# %%
sns.scatterplot(data = diet_df, x = "Carbohydrates (g)", y = "Protein (g)", hue = "Protein (g)")
# Out:
# <AxesSubplot:xlabel='Carbohydrates (g)', ylabel='Protein (g)'>

# %% [markdown]
# # Histograma das proteinas dos elementos da dieta

# %%
sns.displot(diet_df, x = "Protein (g)", bins = 10)
